# %%
from sympy import *
import math


α0 = 0
α1 = Symbol("α1")
α2 = Symbol("α2")
α3 = Symbol("α3")
α4 = Symbol("α4")
α5 = Symbol("α5")
α6 = 0

a0 = 0
a1 = Symbol("a1")
a2 = Symbol("a2")
a3 = Symbol("a3")
a4 = Symbol("a4")
a5 = Symbol("a5")
a6 = 0

θ1 = Symbol("θ1")
θ2 = Symbol("θ2")
θ3 = Symbol("θ3")
θ4 = Symbol("θ4")
θ5 = Symbol("θ5")
θ6 = Symbol("θ6")

d1 = Symbol("d1")
d2 = Symbol("d2")
d3 = Symbol("d3")
d4 = Symbol("d4")
d5 = Symbol("d5")
d6 = Symbol("d6")

nx = Symbol("nx")
ny = Symbol("ny")
nz = Symbol("nz")
ox = Symbol("ox")
oy = Symbol("oy")
oz = Symbol("oz")
ax = Symbol("ax")
ay = Symbol("ay")
az = Symbol("az")
px = Symbol("px")
py = Symbol("py")
pz = Symbol("pz")

# c1 = cos(θ1)
# s1 = sin(θ1)
# c2 = cos(θ2)
# s2 = sin(θ2)
# c3 = cos(θ3)
# s3 = sin(θ3)
# c4 = cos(θ4)
# s4 = sin(θ4)
# c5 = cos(θ5)
# s5 = sin(θ5)
# c6 = cos(θ6)
# s6 = sin(θ6)

# cα1 = cos(α1)
# sα1 = sin(α1)
# cα2 = cos(α2)
# sα2 = sin(α2)
# cα3 = cos(α3)
# sα3 = sin(α3)
# cα4 = cos(α4)
# sα4 = sin(α4)
# cα5 = cos(α5)
# sα5 = sin(α5)
# cα6 = cos(α6)
# sα6 = sin(α6)

c1 = Symbol("c1")
s1 = Symbol("s1")
c2 = Symbol("c2")
s2 = Symbol("s2")
c3 = Symbol("c3")
s3 = Symbol("s3")
c4 = Symbol("c4")
s4 = Symbol("s4")
c5 = Symbol("c5")
s5 = Symbol("s5")
c6 = Symbol("c6")
s6 = Symbol("s6")

cα1 = Symbol("cα1")
sα1 = Symbol("sα1")
cα2 = Symbol("cα2")
sα2 = Symbol("sα2")
cα3 = Symbol("cα3")
sα3 = Symbol("sα3")
cα4 = Symbol("cα4")
sα4 = Symbol("sα4")
cα5 = Symbol("cα5")
sα5 = Symbol("sα5")
cα6 = Symbol("cα6")
sα6 = Symbol("sα6")


T01 = Matrix([
    [ c1,  -s1,   0,   0  ],
    [ s1,   c1,   0,   0  ],
    [  0,    0,   1,  d1  ],
    [  0,    0,   0,   1  ],
])
T12 = Matrix([
    [    c2,    -s2,     0,      a1 ],
    [ s2*c1,  c2*c1,   -s1,  -d2*s1 ],
    [ s2*s1,  c2*s1,    c1,   d2*c1 ],
    [     0,      0,     0,       1 ],
])
T23 = Matrix([
    [    c3,    -s3,     0,      a2  ],
    [ s3*c2,  c3*c2,   -s2,  -d3*s2 ],
    [ s3*s2,  c3*s2,    c2,   d3*c2 ],
    [     0,      0,     0,       1 ],
])
T34 = Matrix([
    [    c4,    -s4,      0,      a3  ],
    [ s4*c3,  c4*c3,   -s3,  -d4*s3 ],
    [ s4*s3,  c4*s3,    c3,   d4*c3 ],
    [     0,      0,     0,       1 ],
])
T45 = Matrix([
    [    c5,    -s5,     0,      a4  ],
    [ s5*c4,  c5*c4,   -s4,  -d5*s4 ],
    [ s5*s4,  c5*s4,    c4,   d5*c4 ],
    [     0,      0,     0,       1 ],
])
T56 = Matrix([
    [    c6,    -s6,     0,      a5  ],
    [ s6*c5,  c6*c5,   -s5,  -d6*s5 ],
    [ s6*s5,  c6*s5,    c5,   d6*c5 ],
    [     0,      0,     0,       1 ],
])

# %%
f1 = a3*c3 + d4*sα3*s3 + a2
f2 = a3*cα2*s3 - d4*sα3*cα2*c3 - d4*sα2*cα3 - d3*sα2
f3 = a3*sα2*s3 - d4*sα3*sα2*c3 + d4*cα2*cα3 + d3*cα2

g1 = c2*f1 - s2*f2 + a1
g2 = s2*cα1*f1 + c2*cα1*f2 - sα1*f3 - d2*sα1
g3 = s2*sα1*f1 + c2*sα1*f2 + cα1*f3 + d2*cα1

k1 = f1
k2 = -f2
k3 = f1**2 + f2**2 + f3**2 + a1**2 + d2**2 + 2*d2*f3
k4 = f3*cα1 + d2*α1

# %%
r = px**2 + py**2 + pz**2
z = pz


u2 = Symbol("u2")
u3 = Symbol("u3")

# c2 = (1-u2**2) / (1+u2**2)
# s2 = 2*u2 / (1+u2**2)
c3 = (1-u3**2) / (1+u3**2)
s3 = 2*u3 / (1+u3**2)

display((r-k3)**2/4*a1**2 + (z-k4)**2/sα1**2 -k1**2 - k2**2)
# Out:
# a1**2*(-a1**2 - d2**2 - 2*d2*(a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3) + px**2 + py**2 + pz**2 - (a2 + a3*c3 + d4*s3*sα3)**2 - (a3*cα2*s3 - c3*cα2*d4*sα3 - cα3*d4*sα2 - d3*sα2)**2 - (a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3)**2)**2/4 - (a2 + a3*c3 + d4*s3*sα3)**2 - (-a3*cα2*s3 + c3*cα2*d4*sα3 + cα3*d4*sα2 + d3*sα2)**2 + (-cα1*(a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3) - d2*α1 + pz)**2/sα1**2

# %%
a1=5.404018878936768
α1=90
d1=95.59999084472656
a2=185.2779083251953
α2=0
d2=27.469284057617188
a3=0
α3=90
d3=14.665228843688965
a4=0
α4=90
d4=140
a5=0
α5=90
d5=0
a6=0
α6=0
d6=91389.109375

cα1 = math.cos(α1)
sα1 = math.sin(α1)
cα2 = math.cos(α2)
sα2 = math.sin(α2)
cα3 = math.cos(α3)
sα3 = math.sin(α3)
cα4 = math.cos(α4)
sα4 = math.sin(α4)
cα5 = math.cos(α5)
sα5 = math.sin(α5)
cα6 = math.cos(α6)
sα6 = math.sin(α6)


px = 300.426513671875
py = -184.43377685546875
pz = 242.9727783203125




display((r-k3)**2/4*a1**2 + (z-k4)**2/sα1**2 -k1**2 - k2**2)
# Out:
# -(a2 + a3*c3 + d4*s3*sα3)**2 - (-a3*cα2*s3 + c3*cα2*d4*sα3 + cα3*d4*sα2 + d3*sα2)**2 + 1.25120423006801*(c2*sα1*(a3*cα2*s3 - c3*cα2*d4*sα3 - cα3*d4*sα2 - d3*sα2) + cα1*d2 - d2*α1 + s2*sα1*(a2 + a3*c3 + d4*s3*sα3))**2 + 7.30085501097625*(-a1**2 - d2**2 - 2*d2*(a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3) + (a1 + c2*(a2 + a3*c3 + d4*s3*sα3) - s2*(a3*cα2*s3 - c3*cα2*d4*sα3 - cα3*d4*sα2 - d3*sα2))**2 - (a2 + a3*c3 + d4*s3*sα3)**2 - (a3*cα2*s3 - c3*cα2*d4*sα3 - cα3*d4*sα2 - d3*sα2)**2 - (a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3)**2 + (c2*cα1*(a3*cα2*s3 - c3*cα2*d4*sα3 - cα3*d4*sα2 - d3*sα2) + cα1*s2*(a2 + a3*c3 + d4*s3*sα3) - d2*sα1 - sα1*(a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3))**2 + (c2*sα1*(a3*cα2*s3 - c3*cα2*d4*sα3 - cα3*d4*sα2 - d3*sα2) + cα1*d2 + cα1*(a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3) + s2*sα1*(a2 + a3*c3 + d4*s3*sα3))**2)**2

# %%
solve(
    a1**2*(-a1**2 - d2**2 - 2*d2*(2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1)) + px**2 + py**2 + pz**2 - (a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))**2 - (2*a3*cα2*u3/(u3**2 + 1) - cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) - cα3*d4*sα2 - d3*sα2)**2 - (2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1))**2)**2/4 - (a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))**2 - (-2*a3*cα2*u3/(u3**2 + 1) + cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) + cα3*d4*sα2 + d3*sα2)**2 + (-cα1*(2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1)) - d2*α1 + pz)**2/sα1**2
    , u3
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-86c57e1ffc1a> in <module>()
#       1 solve(
#       2     a1**2*(-a1**2 - d2**2 - 2*d2*(2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1)) + px**2 + py**2 + pz**2 - (a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))**2 - (2*a3*cα2*u3/(u3**2 + 1) - cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) - cα3*d4*sα2 - d3*sα2)**2 - (2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1))**2)**2/4 - (a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))**2 - (-2*a3*cα2*u3/(u3**2 + 1) + cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) + cα3*d4*sα2 + d3*sα2)**2 + (-cα1*(2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1)) - d2*α1 + pz)**2/sα1**2
# ----> 3     , u3
#       4 )
#
# ...

# %%
simplify(a1**2*(-a1**2 - d2**2 - 2*d2*(2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1)) + px**2 + py**2 + pz**2 - (a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))**2 - (2*a3*cα2*u3/(u3**2 + 1) - cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) - cα3*d4*sα2 - d3*sα2)**2 - (2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1))**2)**2/4 - (a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))**2 - (-2*a3*cα2*u3/(u3**2 + 1) + cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) + cα3*d4*sα2 + d3*sα2)**2 + (-cα1*(2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1)) - d2*α1 + pz)**2/sα1**2)
# Out:
# (a1**2*sα1**2*(2*d2*(u3**2 + 1)*(2*a3*sα2*u3 + cα2*(u3**2 + 1)*(cα3*d4 + d3) + d4*sα2*sα3*(u3**2 - 1)) + (u3**2 + 1)**2*(a1**2 + d2**2 - px**2 - py**2 - pz**2) + (a2*(u3**2 + 1) - a3*(u3**2 - 1) + 2*d4*sα3*u3)**2 + (2*a3*cα2*u3 + cα2*d4*sα3*(u3**2 - 1) - sα2*(u3**2 + 1)*(cα3*d4 + d3))**2 + (2*a3*sα2*u3 + cα2*(u3**2 + 1)*(cα3*d4 + d3) + d4*sα2*sα3*(u3**2 - 1))**2)**2 - 4*sα1**2*(u3**2 + 1)**2*((a2*(u3**2 + 1) - a3*(u3**2 - 1) + 2*d4*sα3*u3)**2 + (2*a3*cα2*u3 + cα2*d4*sα3*(u3**2 - 1) - sα2*(u3**2 + 1)*(cα3*d4 + d3))**2) + 4*(u3**2 + 1)**2*(cα1*(2*a3*sα2*u3 + cα2*(u3**2 + 1)*(cα3*d4 + d3) + d4*sα2*sα3*(u3**2 - 1)) + (u3**2 + 1)*(d2*α1 - pz))**2)/(4*sα1**2*(u3**2 + 1)**4)

# %%
-(a2 + a3*c3 + d4*s3*sα3)**2 + 1.25120423006801*(-cα1*(a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3) - d2*α1 + 242.972778320313)**2 - (-a3*cα2*s3 + c3*cα2*d4*sα3 + cα3*d4*sα2 + d3*sα2)**2 + 7.30085501097625*(-a1**2 - d2**2 - 2*d2*(a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3) - (a2 + a3*c3 + d4*s3*sα3)**2 - (a3*cα2*s3 - c3*cα2*d4*sα3 - cα3*d4*sα2 - d3*sα2)**2 - (a3*s3*sα2 - c3*d4*sα2*sα3 + cα2*cα3*d4 + cα2*d3)**2 + 183307.679166902)**2
# Out:
# -15664.908676767*(-u3**2 + 1)**2/(u3**2 + 1)**2 - (250.319065808156*u3/(u3**2 + 1) + 185.277908325195)**2 + 7.30085501097625*(-15664.908676767*(-u3**2 + 1)**2/(u3**2 + 1)**2 - (250.319065808156*u3/(u3**2 + 1) + 185.277908325195)**2 + 182854.289042863)**2 + 6338723.62136308

# %%
a1=5.404018878936768
α1=90
d1=95.59999084472656
a2=185.2779083251953
α2=0
d2=27.469284057617188
a3=0
α3=90
d3=14.665228843688965
a4=0
α4=90
d4=140
a5=0
α5=90
d5=0
a6=0
α6=0
d6=91389.109375

cα1 = math.cos(α1)
sα1 = math.sin(α1)
cα2 = math.cos(α2)
sα2 = math.sin(α2)
cα3 = math.cos(α3)
sα3 = math.sin(α3)
cα4 = math.cos(α4)
sα4 = math.sin(α4)
cα5 = math.cos(α5)
sα5 = math.sin(α5)
cα6 = math.cos(α6)
sα6 = math.sin(α6)


px = 300.426513671875
py = -184.43377685546875
pz = 242.9727783203125

# %%
solve(
    [
        (k1*c2 + k2*s2)*2*a1 + k3 - r.dot(r),
        (k1*s2 - k2*c2)*sα1 + k4 - pz
    ], 
    [u2,u3]
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-af8d6f3fea4e> in <module>()
#       4         (k1*s2 - k2*c2)*sα1 + k4 - pz
#       5     ],
# ----> 6     [u2,u3]
#       7 )
#
# C:\Users\alee\AppData\Local\Programs\Python\Python36-32\lib\site-packages\sympy-1.1.2.dev0-py3.6.egg\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1066         solution = _solve(f[0], *symbols, **flags)
#    1067     else:
# -> 1068         solution = _solve_system(f, symbols, **flags)
#    1069
#    1070     #
#
# C:\Users\alee\AppData\Local\Programs\Python\Python36-32\lib\site-packages\sympy-1.1.2.dev0-py3.6.egg\sympy\solvers\solvers.py in _solve_system(exprs, symbols, **flags)
#    1733             else:
#    1734                 try:
# -> 1735                     result = solve_poly_system(polys, *symbols)
#    1736                     solved_syms = symbols
# ...

# %%
T34
# Out:
# Matrix([
# [        cos(θ4),        -sin(θ4),        0,          a3],
# [sin(θ4)*cos(θ3), cos(θ3)*cos(θ4), -sin(θ3), -d4*sin(θ3)],
# [sin(θ3)*sin(θ4), sin(θ3)*cos(θ4),  cos(θ3),  d4*cos(θ3)],
# [              0,               0,        0,           1]])

# %% [raw]
# u3 = -(5.59461024170251e+28*u2 + 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)

# %%
solve(
    21.6160755157471*u2*(-125.159532904078*(-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 125.159532904078)/((u2**2 + 1)*((-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 1)) + (-10.8080377578735*u2**2 + 10.8080377578735)*(250.319065808156*(-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))/(((-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 1)*(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)) + 185.277908325195)/(u2**2 + 1) + (-125.159532904078*(-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 125.159532904078)**2/((-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 1)**2 + (250.319065808156*(-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))/(((-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 1)*(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)) + 185.277908325195)**2 - 182854.289042863
    , u2
)

# %%
a1**2 + d2**2 + 2*d2*(2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1)) - px**2 - py**2 - pz**2 + 21.6160755157471*u2*(-2*a3*cα2*u3/(u3**2 + 1) + cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) + cα3*d4*sα2 + d3*sα2)/(u2**2 + 1) + 10.8080377578735*(-u2**2 + 1)*(a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))/(u2**2 + 1) + (a2 + a3*(-u3**2 + 1)/(u3**2 + 1) + 2*d4*sα3*u3/(u3**2 + 1))**2 + (2*a3*cα2*u3/(u3**2 + 1) - cα2*d4*sα3*(-u3**2 + 1)/(u3**2 + 1) - cα3*d4*sα2 - d3*sα2)**2 + (2*a3*sα2*u3/(u3**2 + 1) + cα2*cα3*d4 + cα2*d3 - d4*sα2*sα3*(-u3**2 + 1)/(u3**2 + 1))**2
# Out:
# 21.6160755157471*u2*(-125.159532904078*(-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 125.159532904078)/((u2**2 + 1)*((-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))**2/(5.34726818769445e+29*u2**2 + 8.28189159408074e+28*u2 + 5.9067292118647e+29)**2 + 1)) + (-10.8080377578735*u2**2 + 10.8080377578735)*(250.319065808156*(-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068e+59*u2**2 - 3.10681288210718e+58*u2 - 1.05282884026432e+59))/(((-5.59461024170251e+28*u2 - 1.73205080756888*sqrt(-1.05282884026432e+59*u2**4 - 3.10681288210718e+58*u2**3 - 2.12852092332068
# ...

# %%
math.sin
# Out:
# <function math.sin>
